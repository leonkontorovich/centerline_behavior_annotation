# %% [markdown]
# ## Actual code

# %%
#import pckgs
import cv2
import tifffile as tiff
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

import os
import shutil
from natsort import natsorted
import sys
import re

from scipy.interpolate import splprep, splev

from skimage.morphology import medial_axis, skeletonize
from skimage import data
from skimage.util import invert
import skimage.graph

# %%
#calculate median and do inverse function
def median_and_inverse(bg_file_path):
    retval, mats=cv2.imreadmulti(bg_file_path)
    bg_video=np.asarray(mats)
    bg_video_med=np.median(bg_video, axis=0).astype(dtype=np.uint8)  
    bg_video_med=cv2.bitwise_not(bg_video_med)
    return bg_video_med

# %%
#save MEDIAN projection as a background in the background folder
main_path='/groups/zimmer/Ulises/wbfm/chemotaxis_assay/2020_Only_behaviour/datasets/'

for roots, dirs, files in os.walk(main_path):
    #if 'string' to detect directory with background
    if 'bg' in roots:
        #for every file in that directory
        for single_file in files:
            if 'bg-channel-0-_MMStack.ome.tif' in single_file:
                #print(os.path.join(roots,single_file)+'\n')
                tiff.imsave(os.path.join(roots,re.split('.ome.tif',single_file)[0]+'_Median_BG.tiff'),median_and_inverse(os.path.join(roots,single_file)))#,
                print('\n\n')
# Out:
# /groups/zimmer/Ulises/wbfm/chemotaxis_assay/2020_Only_behaviour/datasets/dataset_20200608/2020-06-08_11-35-19_control_worm3-channel-0-/2020-06-08_11-56-54_control_worm3_bg-channel-0-/2020-06-08_11-56-54_control_worm3_bg-channel-0-_MMStack.ome.tif
#
#
#
#
# /groups/zimmer/Ulises/wbfm/chemotaxis_assay/2020_Only_behaviour/datasets/dataset_20200608/2020-06-08_15-28-37_chemo_worm2-channel-0-/2020-06-08_15-55-28_chemo_worm2_bg-channel-0-/2020-06-08_15-55-28_chemo_worm2_bg-channel-0-_MMStack.ome.tif
#
#
#
#
# /groups/zimmer/Ulises/wbfm/chemotaxis_assay/2020_Only_behaviour/datasets/dataset_20200608/2020-06-08_16-02-48_chemo_worm3-channel-0-/2020-06-08_16-25-20_chemo_worm3_bg-channel-0-/2020-06-08_16-25-20_chemo_worm3_bg-channel-0-_MMStack.ome.tif
#
#
#
#
# ...

# %%
#not very proud of this code. Goes over directories and
#if there is no background folder, or if the background folder is called copied_bg, it copies the source_bg_image to it

main_path='/groups/zimmer/Ulises/wbfm/chemotaxis_assay/2020_Only_behaviour/datasets/'

source_bg_image=os.path.join(main_path,
    'dataset_20200609/2020-06-09_10-12-53_control_worm1-channel-0-/2020-06-09_10-21-16_control_worm1_bg-channel-0-/2020-06-09_10-21-16_control_worm1_bg-channel-0-_MMStack_Median_BG.tiff')

for roots, dirs, files in os.walk(main_path):
    #if 'string' to detect directory with background
    if 'worm' in roots and 'bg' not in roots:
        print('Root Directory: '+ roots)
        if not dirs:
            print('     directory empty of bg folder\n')
            #create one
            print('creating a bg folder:')
            dst_folder=(os.path.join(roots,re.split('/',roots)[-1]+'copied_bg'))
            dst_file=os.path.join(dst_folder,re.split('/',source_bg_image)[-1])
            #print(dst_file)
            try:
                print('trying to copy folder..')
                os.mkdir(dst_folder)
                print('trying to copy file..')
                shutil.copyfile(source_bg_image,dst_file);
            except: print('maybe file cant be copied because directory does not exist. Maybe it cant copy bc it already exists')
            print('\n\n')
            #sys.exit("MY Personal Error message")
            
        elif 'copied_bg' in str(dirs):
            print('directories with copied_bg folder :')
            dst_folder=(os.path.join(roots,re.split('/',roots)[-1]+'copied_bg'))
            dst_file=os.path.join(dst_folder,re.split('/',source_bg_image)[-1])
            shutil.copyfile(source_bg_image,dst_file);
            print(dirs)#'bg folder is: '+str(dirs))
# Out:
# Root Directory: /groups/zimmer/Ulises/wbfm/chemotaxis_assay/2020_Only_behaviour/datasets/dataset_20200605/2020-06-05_16-46-41_worm1-channel-0-
# directories with copied_bg folder :
# ['2020-06-05_16-46-41_worm1-channel-0-copied_bg']
# Root Directory: /groups/zimmer/Ulises/wbfm/chemotaxis_assay/2020_Only_behaviour/datasets/dataset_20200605/2020-06-05_18-01-23_worm4-channel-0-
# directories with copied_bg folder :
# ['2020-06-05_18-01-23_worm4-channel-0-copied_bg']
# Root Directory: /groups/zimmer/Ulises/wbfm/chemotaxis_assay/2020_Only_behaviour/datasets/dataset_20200605/2020-06-05_18-30-39_worm6-channel-0-
# directories with copied_bg folder :
# ['2020-06-05_18-30-39_worm6-channel-0-copied_bg']
# Root Directory: /groups/zimmer/Ulises/wbfm/chemotaxis_assay/2020_Only_behaviour/datasets/dataset_20200605/2020-06-05_19-00-03_worm7-channel-0-
# directories with copied_bg folder :
# ['2020-06-05_19-00-03_worm7-channel-0-copied_bg']
# ...
