# %% [markdown]
# How it should work:
#
# Iterate over all folders.
# if background folder create background.
# Do med projection and save it in that folder
# if not, use generic background.
# (generated before).
#
#
# delete original ome tiff file? better not just in case

# %%
#define default output path
output_path='/groups/zimmer/Ulises/code/skeleton_outputs/'
try: os.mkdir(output_path)
except: print('Output Directory already exists')
# Out:
# Output Directory already exists

# %% [markdown]
# ## Actual code

# %%
#import pckgs
import cv2
import tifffile as tiff
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

import os
from natsort import natsorted

from scipy.interpolate import splprep, splev

from skimage.morphology import medial_axis, skeletonize
from skimage import data
from skimage.util import invert
import skimage.graph

# %%
#calculate median and do inverse function
def median_and_inverse(bg_file_path):
    retval, mats=cv2.imreadmulti(bg_file_path)
    bg_video=np.asarray(mats)
    bg_video_med=np.median(bg_video, axis=0).astype(dtype=np.uint8)  
    bg_video_med=cv2.bitwise_not(bg_video_med)
    return bg_video_med

# %%
main_path='/groups/zimmer/Ulises/wbfm/chemotaxis_assay/2020_Only_behaviour/'

for roots, dirs, files in os.walk(main_path):
    for single_file in files:
        if 'bg' in single_file and 'ome.tif' in single_file:
            #print(single_file)
            #print(dirs)
            #print(roots)
            tiff.imsave(os.path.join(roots+'_median_bg3.tiff'),median_and_inverse(os.path.join(roots,single_file)))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-0576e7c7eb3e> in <module>
#       7             #print(dirs)
#       8             #print(roots)
# ----> 9             tiff.imsave(os.path.join(roots+'_median_bg3.tiff'),median_and_inverse(os.path.join(roots,single_file)))
#
# <ipython-input-3-984b5d64fd4f> in median_and_inverse(bg_file_path)
#       3     retval, mats=cv2.imreadmulti(bg_file_path)
#       4     bg_video=np.asarray(mats)
# ----> 5     bg_video_med=np.median(bg_video, axis=0).astype(dtype=np.uint8)
#       6     bg_video_med=cv2.bitwise_not(bg_video_med)
#       7     return bg_video_med
#
# <__array_function__ internals> in median(*args, **kwargs)
#
# ~/anaconda3/envs/openCV/lib/python3.7/site-packages/numpy/lib/function_base.py in median(a, axis, out, overwrite_input, keepdims)
#    3519     """
#    3520     r, k = _ureduce(a, func=_median, axis=axis, out=out,
# -> 3521                     overwrite_input=overwrite_input)
#    3522     if keepdims:
#    3523         return r.reshape(k)
#
# ~/anaconda3/envs/openCV/lib/python3.7/site-packages/numpy/lib/function_base.py in _ureduce(a, func, **kwargs)
#    3427         keepdim = (1,) * a.ndim
#    3428
# -> 3429     r = func(a, **kwargs)
#    3430     return r, keepdim
#    3431
#
# ~/anaconda3/envs/openCV/lib/python3.7/site-packages/numpy/lib/function_base.py in _median(a, axis, out, overwrite_input)
#    3553             part = a
#    3554     else:
# -> 3555         part = partition(a, kth, axis=axis)
#    3556
#    3557     if part.shape == ():
#
# <__array_function__ internals> in partition(*args, **kwargs)
#
# ~/anaconda3/envs/openCV/lib/python3.7/site-packages/numpy/core/fromnumeric.py in partition(a, kth, axis, kind, order)
#     746     else:
#     747         a = asanyarray(a).copy(order="K")
# --> 748     a.partition(kth, axis=axis, kind=kind, order=order)
#     749     return a
#     750
#
# KeyboardInterrupt:

# %%
            #if you want to visualize it
#             plt.imshow(median_and_inverse(os.path.join(roots,single_file)))
#             plt.title(single_file)
#             plt.show()
