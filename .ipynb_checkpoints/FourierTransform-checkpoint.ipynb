# %% [markdown]
# ## Trying FTT

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import scipy.fftpack

# %%
# Number of sample points
N = 600
# sample spacing
T = 1.0 / 800.0
x = np.linspace(0.0, N*T, N)
y = np.sin(50.0 * 2.0*np.pi*x) + 0.5*np.sin(80.0 * 2.0*np.pi*x)
print('y shape: '+str(y.shape))
yf = scipy.fftpack.fft(y)
xf = np.linspace(0.0, 1.0//(2.0*T), N//2)
y_axis=2.0/N * np.abs(yf[:N//2])
print('yf shape: '+str(yf.shape))
plt.plot(y)
plt.show()
fig, ax = plt.subplots()
ax.plot(xf, 2.0/N * np.abs(yf[:N//2]))
plt.show()
# Out:
# y shape: (600,)
# yf shape: (600,)

# %%
plt.plot(2.0/N * np.abs(yf[:N//2]))

# %%
plt.plot(np.abs(yf[:N//2]))

# %%
plt.plot((yf[:N//2]))
# Out:
# /users/ulises.rey/anaconda3/envs/openCV/lib/python3.7/site-packages/numpy/core/_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
plt.plot(np.abs(yf))

# %%
N
# Out:
# 600

# %%
csv_filepath='/groups/zimmer/Ulises/code/skeleton_outputs/new2/second_der_np_new.csv'
df = pd.read_csv(csv_filepath, header=None)

# %%
df.head(2)
# Out:
#            0         1         2         3         4         5         6     \
# 0 -2.070417e+06  0.082500 -0.049146 -0.026734 -0.049329 -0.022836 -0.030233
# 1 -2.935835e+05  0.078378 -0.020416 -0.001035 -0.011923  0.001957 -0.000758
#
#        7         8         9     ...      6809      6810      6811      6812  \
# 0 -0.031630 -0.023335 -0.025871  ...  0.039890  0.033654  0.036814  0.040905
# 1 -0.003713 -0.003002  0.001329  ...  0.022873  0.019882  0.025282  0.029951
#
#        6813      6814      6815      6816      6817      6818
# 0  0.036258  0.034664  0.034236  0.041494  0.029466  0.033340
# 1  0.026719  0.022910  0.025697  0.039643  0.035064  0.024816
#
# [2 rows x 6819 columns]

# %%
#csv_filepath='/groups/zimmer/Ulises/code/skeleton_outputs/new/second_der_np_new.csv'
csv_filepath='/groups/zimmer/Ulises/code/skeleton_outputs/new2/csv_writerK.csv'

K = np.genfromtxt(csv_filepath, delimiter=',')

# %%
K.shape
# Out:
# (123, 100)

# %%
plt.figure(figsize=(20,50))
plt.imshow(K, cmap='bwr', vmin=-0.0003, vmax=0.0003)
plt.savefig('Kymograph_test2.eps', format='eps', dpi=10)

# %%
for i, segment in enumerate(K.T):
    #print(segment.shape)
    #plt.plot(segment[1:])
    #plt.show()
    if i%2==0:
        plt.figure(figsize=(20,5))
        ft_segment = scipy.fftpack.fft(segment)
        plt.subplot(121)
        plt.plot(segment)
        plt.subplot(122)
        plt.plot(np.abs(1/ft_segment))
        axs = plt.gca()
        axs.set_xlim([0,1500])
        axs.set_ylim([-200,200])
        plt.show()
    if i ==100: break

# %%
plt.figure(figsize=(20,20))

plt.imshow(df.values, cmap='bwr', vmin=df.values.min(), vmax=df.values.max())
#plt.colorbar()

# %%
df.shape
# Out:
# (100, 6819)

# %%
plt.plot(df.iloc[90].values)

# %%
yf = scipy.fftpack.fft(df.iloc[10].values)
plt.subplot(211)
plt.plot(df.iloc[10].values)
plt.subplot(212)
plt.plot(yf)
# Out:
# /users/ulises.rey/anaconda3/envs/openCV/lib/python3.7/site-packages/numpy/core/_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
# Out:
# /users/ulises.rey/anaconda3/envs/openCV/lib/python3.7/site-packages/numpy/core/_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
